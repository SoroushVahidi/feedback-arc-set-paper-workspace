# %%
import pandas as pd
import networkx as nx
#from google.colab import drive
#drive.mount('/content/drive')

def read_graph(csv_path):
    print("📥 Reading graph CSV...")
    df = pd.read_csv(csv_path)
    df.rename(columns={
        'Source Node  ID': 'source',
        'Target Node ID': 'target',
        'Edge Weight': 'weight'
    }, inplace=True)
    df['source'] = df['source'].astype(str)
    df['target'] = df['target'].astype(str)
    edges = list(df.itertuples(index=False, name=None))
    node_set = sorted(set(u for u, v, _ in edges).union(v for u, v, _ in edges))
    node_to_index = {node: i for i, node in enumerate(node_set)}
    index_to_node = {i: node for node, i in node_to_index.items()}
    edges_indexed = [(node_to_index[u], node_to_index[v], float(w)) for (u, v, w) in edges]
    print(f"✅ Graph loaded: {len(edges_indexed)} edges, {len(node_to_index)} nodes")
    return edges_indexed, node_to_index, index_to_node


def load_initial_scores(csv_path, node_to_index):
    print("📥 Reading ranking CSV...")
    df = pd.read_csv(csv_path)
    df['Node ID'] = df['Node ID'].astype(str).str.strip()
    rank_map = {row['Node ID']: row['Order'] for _, row in df.iterrows()}

    scores = {}
    for node_str, idx in node_to_index.items():
        if node_str in rank_map and idx not in scores:
            scores[idx] = int(rank_map[node_str])

    max_rank = max(scores.values(), default=0) + 1
    for node_str, idx in node_to_index.items():
        if idx not in scores:
            scores[idx] = max_rank
            max_rank += 1

    print(f"✅ Ranking loaded: {len(scores)} scores assigned")
    return scores


def check_scc_topological_violations(edge_csv, ranking_csv):
    print("🚀 Starting SCC violation check...")
    edges, node_to_index, index_to_node = read_graph(edge_csv)
    scores = load_initial_scores(ranking_csv, node_to_index)

    print("🔧 Building directed graph...")
    G = nx.DiGraph()
    G.add_weighted_edges_from(edges)
    print(f"✅ Graph constructed with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges")

    print("🔍 Computing strongly connected components...")
    sccs = list(nx.strongly_connected_components(G))
    node_to_scc = {}
    for scc_index, scc in enumerate(sccs):
        for node in scc:
            node_to_scc[node] = scc_index
    print(f"✅ Found {len(sccs)} strongly connected components")

    print("🛠️ Building SCC DAG...")
    scc_dag = nx.DiGraph()
    for u, v, _ in edges:
        if u in node_to_scc and v in node_to_scc:
            scc_u = node_to_scc[u]
            scc_v = node_to_scc[v]
            if scc_u != scc_v:
                scc_dag.add_edge(scc_u, scc_v)
    print(f"✅ DAG has {scc_dag.number_of_nodes()} nodes and {scc_dag.number_of_edges()} edges")

    print("📏 Performing topological sort on SCC DAG...")
    scc_order = list(nx.topological_sort(scc_dag))
    scc_rank = {scc: i for i, scc in enumerate(scc_order)}
    print(f"✅ Topological sort completed")

    print("📊 Checking ranking violations between consecutive nodes (considering reachability)...")
    sorted_nodes = sorted(scores.items(), key=lambda x: x[1])
    violations = []

    for i in range(len(sorted_nodes) - 1):
        u, score_u = sorted_nodes[i]
        v, score_v = sorted_nodes[i + 1]

        if u not in node_to_scc or v not in node_to_scc:
            continue

        scc_u = node_to_scc[u]
        scc_v = node_to_scc[v]

        if scc_u == scc_v:
            continue

        try:
            if nx.has_path(scc_dag, scc_u, scc_v):
                if scc_rank[scc_u] > scc_rank[scc_v]:
                    violations.append((u, v, scc_u, scc_v, score_u, score_v))
        except nx.NodeNotFound:
            continue

    print(f"❗ Found {len(violations)} violations of topological SCC order in the input ranking.")
    for u, v, su, sv, ru, rv in violations[:20]:
        print(f"Violation: Node {u} (SCC {su}, rank {ru}) is ranked after Node {v} (SCC {sv}, rank {rv})")

    return violations

# %%
violations = check_scc_topological_violations(
    edge_csv="../datasets/connectome_graph.csv",
    ranking_csv="../datasets/35462925.csv"
)
# Out:
# 🚀 Starting SCC violation check...
# 📥 Reading graph CSV...
# ✅ Graph loaded: 5657719 edges, 136648 nodes
# 📥 Reading ranking CSV...
# ✅ Ranking loaded: 136648 scores assigned
# 🔧 Building directed graph...
# ✅ Graph constructed with 136648 nodes and 5657719 edges
# 🔍 Computing strongly connected components...
# ✅ Found 9626 strongly connected components
# 🛠️ Building SCC DAG...
# ✅ DAG has 9624 nodes and 11680 edges
# 📏 Performing topological sort on SCC DAG...
# ✅ Topological sort completed
# 📊 Checking ranking violations between consecutive nodes (considering reachability)...
# ❗ Found 0 violations of topological SCC order in the input ranking.

# %%
import pandas as pd
import itertools

def partition_recursive(scores, level, x=3, start=None, end=None):
    # Default range
    if start is None:
        start = min(scores.values())
    if end is None:
        end = max(scores.values())

    # Get sorted list of node IDs in range (lowest RAM way)
    sorted_nodes = sorted((node for node, score in scores.items() if start <= score <= end),
                          key=lambda node: scores[node])

    # Use index ranges instead of copying node sublists repeatedly
    index_ranges = [(0, len(sorted_nodes))]

    for _ in range(level):
        new_ranges = []
        for start_idx, end_idx in index_ranges:
            size = end_idx - start_idx
            base = size // x
            remainder = size % x
            offsets = [base + (1 if i == x - 1 else 0) for i in range(x)]

            sub_start = start_idx
            for s in offsets:
                new_ranges.append((sub_start, sub_start + s))
                sub_start += s
        index_ranges = new_ranges

    # Yield final partitions as sets
    return [set(sorted_nodes[start:end]) for start, end in index_ranges]

def partition_flat(scores, level, x=3, start=None, end=None):
    # Same input and output format as partition_recursive

    # Determine score bounds
    if start is None:
        start = min(scores.values())
    if end is None:
        end = max(scores.values())

    # Collect and sort nodes within the score range
    sorted_nodes = sorted(
        (node for node, score in scores.items() if start <= score <= end),
        key=lambda node: scores[node]
    )

    # Compute total partitions
    num_parts = x ** level
    total = len(sorted_nodes)
    base_size = total // num_parts
    remainder = total % num_parts

    # Divide into parts with balanced sizes
    parts = []
    idx = 0
    for i in range(num_parts):
        size = base_size + (1 if i < remainder else 0)
        parts.append(set(sorted_nodes[idx:idx + size]))
        idx += size

    return parts


def evaluate_within_parent_groups(scores, parts, edges_indexed, x):
    num_parts = len(parts)
    part_map = {}
    for i, part in enumerate(parts):
        for node in part:
            part_map[node] = i

    # Compute inter-part weights
    part_weights = [[0] * num_parts for _ in range(num_parts)]
    for u, v, w in edges_indexed:
        i, j = part_map[u], part_map[v]
        part_weights[i][j] += w

    inconsistencies = []
    group_count = num_parts // x

    for g in range(group_count):
        group = list(range(g * x, (g + 1) * x))
        part_ranks = [min(scores[node] for node in parts[i]) for i in group]
        initial_order = sorted(group, key=lambda i: part_ranks[group.index(i)])

        def forward_weight(order):
            weight = 0
            for i in range(x):
                for j in range(i + 1, x):
                    weight += part_weights[order[i]][order[j]]
            return weight

        perms = list(itertools.permutations(group))
        weights = [(perm, forward_weight(perm)) for perm in perms]
        best_perm, best_weight = max(weights, key=lambda x: x[1])
        initial_weight = forward_weight(initial_order)

        if tuple(initial_order) != best_perm:
            inconsistencies.append({
                "group": group,
                "initial_order": tuple(initial_order),
                "best_order": best_perm,
                "initial_weight": initial_weight,
                "best_weight": best_weight
            })

    return inconsistencies

def find_first_inconsistent_level(scores, edges_indexed, max_level=5, x=3):
    for level in range(1, max_level + 1):
        num_blocks = x ** level
        print(f"🔍 Checking level {level} with {num_blocks} blocks (branching factor = {x})...")
        parts = partition_recursive(scores, level, x)
        inconsistencies = evaluate_within_parent_groups(scores, parts, edges_indexed, x)

        if inconsistencies:
            print(f"❌ Inconsistency found at level {level} in {len(inconsistencies)} group(s)")
            for inc in inconsistencies:
                print(f"  Group {inc['group']}:")
                print(f"    Initial order = {inc['initial_order']}, weight = {inc['initial_weight']}")
                print(f"    Best order    = {inc['best_order']}, weight = {inc['best_weight']}")
            return level
        else:
            print(f"✅ Level {level} is consistent")
    print("✅ No inconsistencies found up to max level")
    return None

# %%
def compute_total_forward_weight(edges, scores):
    return sum(w for u, v, w in edges if scores[u] < scores[v])

# === Step 5: Evaluate and Reorder ===
import itertools


def evaluate_and_reorder(scores, parts, edges_indexed, x, start=None, end=None):
    num_parts = len(parts)
    part_map = {}
    for i, part in enumerate(parts):
        for node in part:
            part_map[node] = i

    # Compute part-to-part weights (no change)
    part_weights = [[0] * num_parts for _ in range(num_parts)]
    for u, v, w in edges_indexed:
        if u in part_map and v in part_map:
            i, j = part_map[u], part_map[v]
            part_weights[i][j] += w

    changed = False
    group_count = num_parts // x

    for g in range(group_count):
        group = list(range(g * x, (g + 1) * x))

        def min_rank(i):
            return min(scores[n] for n in parts[i])

        initial_order = sorted(group, key=min_rank)

        def forward_weight(order):
            return sum(
                part_weights[order[i]][order[j]]
                for i in range(x) for j in range(i + 1, x)
            )

        # Memory-efficient permutation search
        best_perm = None
        best_weight = -1
        for perm in itertools.permutations(group):
            w = forward_weight(perm)
            if w > best_weight:
                best_weight = w
                best_perm = perm

        initial_weight = forward_weight(initial_order)

        if tuple(initial_order) != best_perm:
            changed = True
            print(f"  Reordering group {group}:")
            print(f"    Initial order = {tuple(initial_order)}, weight = {initial_weight}")
            print(f"    Best order    = {best_perm}, weight = {best_weight}")

            # Work directly with node generators to reduce memory
            combined = (node for i in group for node in parts[i])
            sorted_combined = sorted(combined, key=lambda n: scores[n])

            new_order = []
            for i in best_perm:
                block_sorted = sorted(parts[i], key=lambda n: scores[n])
                new_order.extend(block_sorted)

            base_score = scores[sorted_combined[0]]
            for new_rank, node in enumerate(new_order):
                if start is None or end is None or start <= scores[node] <= end:
                    scores[node] = base_score + new_rank

    return changed




# === Step 6: Export Final Rankings ===
def finalize_and_export(scores, index_to_node, output_excel):
    n = len(scores)
    ranked = [(str(index_to_node[v]), scores[v]) for v in range(n)]
    ranked.sort(key=lambda x: x[1])
    df = pd.DataFrame(ranked, columns=["Node ID", "Order"])
    df.to_csv(output_excel, index=False)
    print(f"✅ Final ranking saved to {output_excel}")

# === Step 7: Run Full Process ===
graph_file = "../datasets/connectome_graph.csv"
ranking_file = "../datasets/35462925.csv"
output_excel = "../datasets/connectome_scc_ranking.csv"

import math

edges_indexed, node_to_index, index_to_node = read_graph(graph_file)
scores = load_initial_scores(ranking_file, node_to_index)

print("📊 Initial forward weight:")
before_weight = compute_total_forward_weight(edges_indexed, scores)
print(before_weight)

x = 5
start = 0
end = len(scores)-1

max_level = min(int(math.log(end - start + 1, x)), int(math.log(9000000, x)))

print(f"🔁 Evaluating level = {max_level} for partial ranking: scores[{start}:{end}]")

parts = partition_flat(scores, level=max_level, x=x, start=start, end=end)
_ = evaluate_and_reorder(scores, parts, edges_indexed, x=x, start=start, end=end)


print("📈 Forward weight after reordering:")
after_weight = compute_total_forward_weight(edges_indexed, scores)
print(after_weight)

finalize_and_export(scores, index_to_node, output_excel)
# Out:
# 📥 Reading graph CSV...
# ✅ Graph loaded: 5657719 edges, 136648 nodes
# 📥 Reading ranking CSV...
# ✅ Ranking loaded: 136648 scores assigned
# 📊 Initial forward weight:
# 35462925.0
# 🔁 Evaluating level = 7 for partial ranking: scores[0:136647]
# 📈 Forward weight after reordering:
# 35462925.0
# ✅ Final ranking saved to ../datasets/connectome_scc_ranking.csv

# %%
import os
import pandas as pd
import networkx as nx
from itertools import permutations

def compute_scc_optimized_ranking_and_forward_weight(edge_csv, ranking_csv, output_csv):
    print("🚀 Starting SCC-based forward weight optimization...")

    # Step 1: Read graph and initial scores
    edges, node_to_index, index_to_node = read_graph(edge_csv)
    scores = load_initial_scores(ranking_csv, node_to_index)

    print("🔧 Building directed graph...")
    G = nx.DiGraph()
    G.add_weighted_edges_from(edges)
    print(f"✅ Graph constructed: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

    print("🔍 Finding strongly connected components...")
    sccs = list(nx.strongly_connected_components(G))
    node_to_scc = {}
    for i, scc in enumerate(sccs):
        for node in scc:
            node_to_scc[node] = i
    print(f"✅ Found {len(sccs)} strongly connected components")

    print("🛠️ Building SCC DAG...")
    scc_dag = nx.DiGraph()
    scc_dag.add_nodes_from(range(len(sccs)))  # Add all SCCs even if isolated
    for u, v, _ in edges:
        su, sv = node_to_scc[u], node_to_scc[v]
        if su != sv:
            scc_dag.add_edge(su, sv)
    print(f"✅ DAG: {scc_dag.number_of_nodes()} nodes, {scc_dag.number_of_edges()} edges")

    print("📏 Topologically sorting SCCs...")
    try:
        scc_order = list(nx.topological_sort(scc_dag))
    except nx.NetworkXUnfeasible:
        print("❌ Error: SCC DAG is not a DAG (cycle detected)!")
        return None
    print(f"✅ SCC topological sort complete. Order length = {len(scc_order)}")

    print("⚙️ Ranking nodes SCC by SCC...")
    node_order = {}
    current_rank = 0
    visited_scc_ids = set()

    for scc_id in scc_order:
        visited_scc_ids.add(scc_id)
        component = list(sccs[scc_id])
        if len(component)>1:
            print(f"🔹 SCC {scc_id} with {len(component)} nodes")

        if len(component) <= 9 and len(component)>1:
            print("   🔄 Permuting to maximize internal forward weight...")
            initial_sorted = sorted(component, key=lambda n: scores.get(n, float('inf')))
            best_order = []
            max_internal_fw = -1
            for perm in permutations(initial_sorted):
                pos = {node: i for i, node in enumerate(perm)}
                fw = sum(
                    G[u][v]['weight']
                    for u in perm for v in perm
                    if G.has_edge(u, v) and pos[u] < pos[v]
                )
                if fw > max_internal_fw:
                    max_internal_fw = fw
                    best_order = perm
            sorted_nodes = best_order
            print(f"   ✅ Best internal forward weight: {max_internal_fw:.2f}")
        else:
         #   print("   ➡️ Too large for permutation, using initial rank sort")
            sorted_nodes = sorted(component, key=lambda n: scores.get(n, float('inf')))

        for node in sorted_nodes:
            node_order[node] = current_rank
            current_rank += 1

    # Check for unvisited SCCs (possibly isolated or not reachable in DAG)
    all_scc_ids = set(range(len(sccs)))
    unvisited_scc_ids = all_scc_ids - visited_scc_ids
    if unvisited_scc_ids:
        print(f"❗ {len(unvisited_scc_ids)} SCCs were not visited during topological sort.")
        for scc_id in sorted(unvisited_scc_ids)[:5]:
            print(f"  🚫 Skipped SCC {scc_id} with {len(sccs[scc_id])} nodes. Example nodes: {list(sccs[scc_id])[:3]}")

    print("📊 Computing total forward edge weight of new ranking...")
    new_fw = sum(
        w for u, v, w in edges if node_order.get(u, -1) < node_order.get(v, -1)
    )
    print(f"🎯 Total forward edge weight of new ranking: {new_fw:.2f}")

    should_write = True
    if os.path.exists(output_csv):
        print("📁 Comparing with existing ranking...")
        existing_scores = load_initial_scores(output_csv, node_to_index)
        existing_fw = sum(
            w for u, v, w in edges
            if existing_scores.get(u, float('inf')) < existing_scores.get(v, float('inf'))
        )
        print(f"📁 Existing ranking has forward weight: {existing_fw:.2f}")
        if new_fw < existing_fw:
            print("⛔ New ranking is not strictly better. Skipping write.")
            should_write = False

    if should_write:
        print("💾 Writing new ranking to output CSV...")
        ranked = [(index_to_node[n], r) for n, r in sorted(node_order.items(), key=lambda x: x[1])]
        pd.DataFrame(ranked, columns=["Node ID", "Order"]).to_csv(output_csv, index=False)
        print(f"✅ Ranking written to {output_csv}")

    return new_fw

# %%
compute_scc_optimized_ranking_and_forward_weight(
    edge_csv="../datasets/connectome_graph.csv",
    ranking_csv="../datasets/35462925.csv",
    output_csv="../datasets/connectome_scc_ranking.csv"
)
# Out:
# 🚀 Starting SCC-based forward weight optimization...
# 📥 Reading graph CSV...
# ✅ Graph loaded: 5657719 edges, 136648 nodes
# 📥 Reading ranking CSV...
# ✅ Ranking loaded: 136648 scores assigned
# 🔧 Building directed graph...
# ✅ Graph constructed: 136648 nodes, 5657719 edges
# 🔍 Finding strongly connected components...
# ✅ Found 9626 strongly connected components
# 🛠️ Building SCC DAG...
# ✅ DAG: 9626 nodes, 11680 edges
# 📏 Topologically sorting SCCs...
# ✅ SCC topological sort complete. Order length = 9626
# ⚙️ Ranking nodes SCC by SCC...
# 🔹 SCC 2441 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 2555 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 9.00
# 🔹 SCC 2927 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 8.00
# 🔹 SCC 2930 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 12.00
# 🔹 SCC 2940 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 44.00
# 🔹 SCC 2968 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 5.00
# 🔹 SCC 3065 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 18.00
# 🔹 SCC 3081 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 9.00
# 🔹 SCC 3096 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 5.00
# 🔹 SCC 3171 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 5.00
# 🔹 SCC 3192 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 4.00
# 🔹 SCC 3231 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 3246 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 3263 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 5.00
# 🔹 SCC 3316 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 10.00
# 🔹 SCC 3424 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 8.00
# 🔹 SCC 3502 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 7.00
# 🔹 SCC 3716 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 10.00
# 🔹 SCC 3732 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 9.00
# 🔹 SCC 3851 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 3992 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 6.00
# 🔹 SCC 4093 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 6.00
# 🔹 SCC 4167 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 6.00
# 🔹 SCC 4214 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 5.00
# 🔹 SCC 4256 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 19.00
# 🔹 SCC 4492 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 4.00
# 🔹 SCC 4731 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 5.00
# 🔹 SCC 4973 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 5.00
# 🔹 SCC 5042 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 6.00
# 🔹 SCC 5335 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 5.00
# 🔹 SCC 5342 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 5.00
# 🔹 SCC 5439 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 6.00
# 🔹 SCC 5458 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 12.00
# 🔹 SCC 5510 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 6.00
# 🔹 SCC 5658 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 4.00
# 🔹 SCC 5934 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 6.00
# 🔹 SCC 6001 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 4.00
# 🔹 SCC 6005 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 3.00
# 🔹 SCC 6136 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 11.00
# 🔹 SCC 6143 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 14.00
# 🔹 SCC 6221 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 6389 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 4.00
# 🔹 SCC 6735 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 9.00
# 🔹 SCC 6821 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 6940 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 15.00
# 🔹 SCC 6980 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 4.00
# 🔹 SCC 7609 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 8477 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 5.00
# 🔹 SCC 8714 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 3.00
# 🔹 SCC 3941 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 2983 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 69.00
# 🔹 SCC 2402 with 5 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 143.00
# 🔹 SCC 3483 with 7 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 102.00
# 🔹 SCC 4317 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 51.00
# 🔹 SCC 3777 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 15.00
# 🔹 SCC 2908 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 18.00
# 🔹 SCC 2997 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 60.00
# 🔹 SCC 2779 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 17.00
# 🔹 SCC 3829 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 27.00
# 🔹 SCC 4902 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 15.00
# 🔹 SCC 2744 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 28.00
# 🔹 SCC 2774 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 15.00
# 🔹 SCC 3488 with 4 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 128.00
# 🔹 SCC 2362 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 16.00
# 🔹 SCC 3932 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 32.00
# 🔹 SCC 2357 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 15.00
# 🔹 SCC 3168 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 10.00
# 🔹 SCC 2811 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 3273 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 50.00
# 🔹 SCC 3260 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 19.00
# 🔹 SCC 5649 with 4 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 76.00
# 🔹 SCC 3604 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 4992 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 3486 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 9.00
# 🔹 SCC 3394 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 26.00
# 🔹 SCC 4635 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 23.00
# 🔹 SCC 6548 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 5.00
# 🔹 SCC 5547 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 9.00
# 🔹 SCC 4504 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 27.00
# 🔹 SCC 4922 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 3.00
# 🔹 SCC 3787 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 14.00
# 🔹 SCC 3567 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 13.00
# 🔹 SCC 3278 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 26.00
# 🔹 SCC 2330 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 21.00
# 🔹 SCC 4537 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 13.00
# 🔹 SCC 7852 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 3.00
# 🔹 SCC 3194 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 18.00
# 🔹 SCC 4909 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 49.00
# 🔹 SCC 7512 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 19.00
# 🔹 SCC 4736 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 3.00
# 🔹 SCC 7819 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 20.00
# 🔹 SCC 2752 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 27.00
# 🔹 SCC 3533 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 11.00
# 🔹 SCC 3586 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 22.00
# 🔹 SCC 4453 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 3886 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 30.00
# 🔹 SCC 2269 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 22.00
# 🔹 SCC 5977 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 24.00
# 🔹 SCC 4095 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 96.00
# 🔹 SCC 3326 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 3.00
# 🔹 SCC 2614 with 6 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 229.00
# 🔹 SCC 2246 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 41.00
# 🔹 SCC 2847 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 33.00
# 🔹 SCC 3391 with 6 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 74.00
# 🔹 SCC 3676 with 4 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 14.00
# 🔹 SCC 2245 with 5 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 82.00
# 🔹 SCC 2253 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 28.00
# 🔹 SCC 2161 with 126840 nodes
# 🔹 SCC 2671 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 48.00
# 🔹 SCC 2255 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 3.00
# 🔹 SCC 1530 with 4 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 79.00
# 🔹 SCC 1724 with 4 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 53.00
# 🔹 SCC 1728 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 8.00
# 🔹 SCC 1557 with 6 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 261.00
# 🔹 SCC 763 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 83.00
# 🔹 SCC 665 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 1132 with 8 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 278.00
# 🔹 SCC 1133 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 2.00
# 🔹 SCC 1057 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 3.00
# 🔹 SCC 1137 with 3 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 55.00
# 🔹 SCC 1048 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 20.00
# 🔹 SCC 1539 with 2 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 12.00
# 🔹 SCC 1120 with 7 nodes
#    🔄 Permuting to maximize internal forward weight...
#    ✅ Best internal forward weight: 88.00
# 📊 Computing total forward edge weight of new ranking...
# 🎯 Total forward edge weight of new ranking: 35462925.00
# 📁 Comparing with existing ranking...
# 📥 Reading ranking CSV...
# ✅ Ranking loaded: 136648 scores assigned
# 📁 Existing ranking has forward weight: 35462925.00
# 💾 Writing new ranking to output CSV...
# ✅ Ranking written to ../datasets/connectome_scc_ranking.csv
# 35462925.0

# %%
import pandas as pd
import networkx as nx
from collections import Counter



def count_sccs_by_size_fast():
    #print("📥 Reading graph from /content/drive/MyDrive/connectome_graph.csv...")
    df = pd.read_csv("../datasets/connectome_graph.csv")
    df.rename(columns={
        'Source Node  ID': 'source',
        'Target Node ID': 'target',
        'Edge Weight': 'weight'
    }, inplace=True)
    df['source'] = df['source'].astype(str)
    df['target'] = df['target'].astype(str)

    print("🔧 Building graph (fast)...")
    G = nx.DiGraph()
    G.add_weighted_edges_from(zip(df['source'], df['target'], df['weight']))

    print("🔍 Finding strongly connected components...")
    sccs = nx.strongly_connected_components(G)  # generator, memory-efficient
    size_counts = Counter(len(scc) for scc in sccs)

    print("📊 SCC size distribution:")
    for size in sorted(size_counts):
        print(f"Size {size}: {size_counts[size]} component(s)")

    return size_counts

u=count_sccs_by_size_fast()
# Out:
# 🔧 Building graph (fast)...
# 🔍 Finding strongly connected components...
# 📊 SCC size distribution:
# Size 1: 9503 component(s)
# Size 2: 92 component(s)
# Size 3: 17 component(s)
# Size 4: 5 component(s)
# Size 5: 2 component(s)
# Size 6: 3 component(s)
# Size 7: 2 component(s)
# Size 8: 1 component(s)
# Size 126840: 1 component(s)

# %%
import pandas as pd
import networkx as nx

def reorder_by_scc_topology(
    edge_csv: str,
    ranking_csv: str,
    output_csv: str
):
    """
    1. Read edges and initial node ranking.
    2. Compute SCCs and build the condensation DAG.
    3. Topo-sort the SCC graph to maximize forward weight (all edges become forward).
    4. Produce a new node order by SCC order, breaking ties by initial ranking.
    """

    # --- 1. Load graph and initial ranking ---
    df_e = pd.read_csv(edge_csv)
    df_e.rename(columns={
        'Source Node  ID':'source',
        'Target Node ID':'target',
        'Edge Weight':'weight'
    }, inplace=True)
    df_e['source'] = df_e['source'].astype(str)
    df_e['target'] = df_e['target'].astype(str)
    edges = list(df_e[['source','target','weight']].itertuples(index=False, name=None))

    df_r = pd.read_csv(ranking_csv)
    df_r['Node ID'] = df_r['Node ID'].astype(str).str.strip()
    initial_rank = dict(zip(df_r['Node ID'], df_r['Order']))

    G = nx.DiGraph()
    G.add_weighted_edges_from(edges)

    # --- 2. Compute SCCs and condensation DAG ---
    scc_list = list(nx.strongly_connected_components(G))
    # map node -> its SCC index
    node_to_scc = {}
    for i, comp in enumerate(scc_list):
        for n in comp:
            node_to_scc[n] = i

    # Build SCC graph: each edge (u,v,w) becomes edge (node_to_scc[u], node_to_scc[v]) with summed weight
    C = nx.DiGraph()
    for i in range(len(scc_list)):
        C.add_node(i)
    for u, v, w in edges:
        cu, cv = node_to_scc[u], node_to_scc[v]
        if cu != cv:
            if C.has_edge(cu, cv):
                C[cu][cv]['weight'] += w
            else:
                C.add_edge(cu, cv, weight=w)

    # --- 3. Topological sort of the condensation DAG ---
    # In a DAG, any topo order makes all edges forward, so this maximizes forward weight.
    scc_order = list(nx.topological_sort(C))

    # --- 4. Build the new node ordering ---
    new_order = []
    for comp_id in scc_order:
        members = list(scc_list[comp_id])
        # sort within the SCC by initial rank
        members.sort(key=lambda n: initial_rank.get(n, float('inf')))
        new_order.extend(members)

    # --- 5. Write out the new ranking ---
    df_out = pd.DataFrame({
        "Node ID": new_order,
        "Order":   range(len(new_order))
    })
    df_out.to_csv(output_csv, index=False)

    print(f"Reordered {len(new_order)} nodes by SCC topology and saved to {output_csv}")

# %%
import pandas as pd
import networkx as nx
from itertools import permutations
def refine_largest_scc_toposorted_blocks(sz=2030,bias=0,gf=5,edge_path = "../datasets/connectome_graph.csv",output_path = "../datasets/connectome_scc_ranking.csv"):
    import pandas as pd
    import networkx as nx
    from itertools import permutations
    from collections import Counter

    def read_graph(csv_path):
        print("📥 Reading graph CSV...")
        df = pd.read_csv(csv_path)
        df.rename(columns={
            'Source Node  ID': 'source',
            'Target Node ID': 'target',
            'Edge Weight': 'weight'
        }, inplace=True)
        df['source'] = df['source'].astype(str)
        df['target'] = df['target'].astype(str)
        edges = list(df.itertuples(index=False, name=None))
        print(f"✅ Loaded graph with {len(edges)} edges")
        return edges

    def load_initial_ranking(csv_path):
        print("📥 Reading ranking CSV...")
        df = pd.read_csv(csv_path)
        df['Node ID'] = df['Node ID'].astype(str).str.strip()
        ranking = dict(zip(df['Node ID'], df['Order']))
        print(f"✅ Loaded ranking for {len(ranking)} nodes")
        return ranking




    edges = read_graph(edge_path)
    G = nx.DiGraph()
    G.add_weighted_edges_from(edges)

    initial_order = load_initial_ranking(output_path)
    node_order = initial_order.copy()

    sccs = list(nx.strongly_connected_components(G))
    largest_scc = max(sccs, key=len)
    largest_scc_nodes = sorted(
        [node for node in node_order if node in largest_scc],
        key=lambda n: node_order[n]
    )

    total_steps = (len(largest_scc_nodes)-sz-bias) // gf+1


    for step in range(total_steps):
       # reorder_by_scc_topology(
      #  edge_csv="/content/drive/MyDrive/ibm01.csv",
     #   ranking_csv="/content/drive/MyDrive/ibm01_ranking.csv",
    #    output_csv="/content/drive/MyDrive/ibm01_ranking.csv"
#)
  #      node_order = load_initial_ranking(output_path)

    # 2) Recompute the largest_SCC and its sorted node list
        sccs = list(nx.strongly_connected_components(G))
        largest_scc = max(sccs, key=len)
        largest_scc_nodes = sorted(
            [n for n in node_order if n in largest_scc],
            key=lambda n: node_order[n]
        )

        # 3) Now do the full‐graph SCC reorder (if you still want it every time)
        reorder_by_scc_topology(
            edge_csv=edge_path,
            ranking_csv=output_path,
            output_csv=output_path
        )

        # 4) AGAIN re‐read the ranking, rebuild node_order & largest_scc_nodes
        node_order = load_initial_ranking(output_path)
        largest_scc_nodes = sorted(
            [n for n in node_order if n in largest_scc],
            key=lambda n: node_order[n]
        )
        block_nodes = largest_scc_nodes[bias + step * gf : min(len(largest_scc_nodes),bias + step*gf + sz)]
        print(f"\n=== Step {step + 1}/{total_steps} ===")
        print(f"Block size: {len(block_nodes)}")

        # Construct subgraph with all block_nodes explicitly included
        subG = G.subgraph(block_nodes).copy()


        # Debug graph completeness
        print(f"Subgraph nodes: {len(subG.nodes)}, Expected block nodes: {len(block_nodes)}")

        # Check if subG is missing nodes
        missing_in_subG = set(block_nodes) - set(subG.nodes)
        if missing_in_subG:
            print(f"⚠️ {len(missing_in_subG)} nodes missing from subG. Example: {list(missing_in_subG)[:5]}")

        # Decompose block into SCCs
        sub_sccs = list(nx.strongly_connected_components(subG))
        print(f"  Found {len(sub_sccs)} SCCs in block")

        # Track SCC node coverage
        covered_nodes = set()
        node_to_subscc = {}
        for idx, scc in enumerate(sub_sccs):
            covered_nodes.update(scc)
            for node in scc:
                node_to_subscc[node] = idx

        uncovered = set(block_nodes) - covered_nodes
        if uncovered:
            print(f"❌ {len(uncovered)} block nodes not covered by SCCs. Example: {list(uncovered)[:5]}")

        # Build SCC DAG
        # Build SCC DAG and topologically sort the sub-SCCs
        scc_dag = nx.DiGraph()
        scc_dag.add_nodes_from(range(len(sub_sccs)))  # Ensure all SCCs are present, even isolated ones
        for u, v in subG.edges():
            su, sv = node_to_subscc[u], node_to_subscc[v]
            if su != sv:
                scc_dag.add_edge(su, sv)

        scc_order = list(nx.topological_sort(scc_dag))


        # Build new order
        new_block_order = []
        print(f"Total SCCs found: {len(sub_sccs)}")
        print(f"Topologically sorted SCCs: {len(scc_order)}")

        visited_scc_ids = set()
        new_block_order = []

        for scc_id in scc_order:
            visited_scc_ids.add(scc_id)
            scc_nodes = list(sub_sccs[scc_id])
         #   print(f"  ➕ SCC {scc_id} has {len(scc_nodes)} nodes")

            if len(scc_nodes) <= 9:
                best_perm = []
                max_weight = -1
                for perm in permutations(scc_nodes):
                    weight = sum(
                        subG[u][v]['weight']
                        for i, u in enumerate(perm)
                        for j, v in enumerate(perm)
                        if i < j and subG.has_edge(u, v)
                    )
                    if weight > max_weight:
                        max_weight = weight
                        best_perm = perm
                new_block_order.extend(best_perm)
            else:
                sorted_original = sorted(scc_nodes, key=lambda n: node_order[n])
                new_block_order.extend(sorted_original)

        # Detect unvisited SCCs (likely due to being isolated)
        all_scc_ids = set(range(len(sub_sccs)))
        unvisited_scc_ids = all_scc_ids - visited_scc_ids
        if unvisited_scc_ids:
            print(f"❗ {len(unvisited_scc_ids)} SCCs were not visited during topological sort.")
            for scc_id in sorted(unvisited_scc_ids)[:5]:
                print(f"  🚫 Skipped SCC {scc_id} with {len(sub_sccs[scc_id])} nodes. Example nodes: {list(sub_sccs[scc_id])[:3]}")

        # Final check
        print(f"New block order length: {len(new_block_order)}")
        missing = set(block_nodes) - set(new_block_order)
        if missing:
            print(f"❌ Final mismatch in new_block_order: {len(missing)} nodes missing.")
            print(f"  Missing (up to 5): {list(missing)[:5]}")
            raise ValueError("Block nodes missing from new_block_order!")

        print(f"✅ All {len(block_nodes)} nodes successfully added to new_block_order.")


        # ——— Extra debug prints added here ———
        prev_order = node_order.copy()
        print(f"🗂️  Reassigning ranks for Step {step+1}:")
        print(f"   block index range: [{bias + step * gf}:{min(len(largest_scc_nodes), bias + step * gf + sz)}]")

        print(f"   sample prev_order for first 5 block nodes: {[prev_order[n] for n in block_nodes[:5]]}")
        base_rank = min(prev_order[n] for n in block_nodes)
        print(f"   computed base_rank = {base_rank}")
        print(f"   new_block_order sample first5: {new_block_order[:5]}, last5: {new_block_order[-5:]}")
        # ————————————————————————————————

        base_rank = min(node_order[n] for n in block_nodes)
        given = set()
        for i, node in enumerate(new_block_order):
            node_order[node] = base_rank + i
            if node_order[node] in given:
                print(f"⚠️ Duplicate rank {node_order[node]} for node {node}")
            given.add(node_order[node])

        # Full scan for any duplicates anywhere
        all_ranks = list(node_order.values())
        if len(all_ranks) != len(set(all_ranks)):
            duplicates = [r for r, cnt in Counter(all_ranks).items() if cnt > 1]
            print(f"❌ Duplicate ranks detected after step {step + 1} — {len(duplicates)} non-unique ranks found.")
            for rank in duplicates:
                nodes_with_rank = [n for n, r in node_order.items() if r == rank]
                # split into those from this block vs the rest
                in_block     = [n for n in nodes_with_rank if n in new_block_order]
                out_of_block = [n for n in nodes_with_rank if n not in new_block_order]
                print(f"  ▶️ Rank {rank}:")
                # Print each node with its old and new rank
                for n in in_block:
                    print(f"     • In block    {n}: prev rank = {prev_order[n]}, curr rank = {node_order[n]}")
                for n in out_of_block:
                    print(f"     • Outside block {n}: prev rank = {prev_order[n]}, curr rank = {node_order[n]}")
            raise ValueError("Duplicate ranks detected in node_order!")

        df_existing = pd.read_csv(output_path)
        df_existing['Node ID'] = df_existing['Node ID'].astype(str).str.strip()
        existing_order = dict(zip(df_existing['Node ID'], df_existing['Order']))
        existing_fw = sum(
            w for u, v, w in edges
            if existing_order.get(u, float('inf')) < existing_order.get(v, float('inf'))
        )

        new_fw = sum(
            w for u, v, w in edges
            if node_order.get(u, float('inf')) < node_order.get(v, float('inf'))
        )

        print(f"Step {step + 1}: New FW = {new_fw:.2f}, Existing FW = {existing_fw:.2f}")

        if new_fw > existing_fw:
            print("✅ Improvement detected. Saving new ranking.")
            ranked = [(node, order) for node, order in sorted(node_order.items(), key=lambda x: x[1])]
            pd.DataFrame(ranked, columns=["Node ID", "Order"]).to_csv(output_path, index=False)
        else:
            if existing_fw > new_fw:
                print("↩️  Reverting to better saved ranking.")
                node_order = existing_order.copy()
            else:
                print("⏭️  No strict improvement in either direction. Keeping current ranking in memory.")

# %%
refine_largest_scc_toposorted_blocks()
# Out:
# 📥 Reading graph CSV...
# ✅ Loaded graph with 5657719 edges
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 136648 nodes
# Reordered 136648 nodes by SCC topology and saved to ../datasets/connectome_scc_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 136648 nodes
#
# === Step 1/24963 ===
# Block size: 2030
# Subgraph nodes: 2030, Expected block nodes: 2030
#   Found 1916 SCCs in block
# Total SCCs found: 1916
# Topologically sorted SCCs: 1916
# New block order length: 2030
# ✅ All 2030 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 1:
#    block index range: [0:2030]
#    sample prev_order for first 5 block nodes: [7602, 7603, 7604, 7605, 7606]
#    computed base_rank = 7602
#    new_block_order sample first5: ['720575940626352176', '720575940625413763', '720575940632852817', '720575940633336476', '720575940626310686'], last5: ['720575940613522413', '720575940624123174', '720575940628832516', '720575940630569413', '720575940622444780']
# Step 1: New FW = 35462925.00, Existing FW = 35462925.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 136648 nodes by SCC topology and saved to ../datasets/connectome_scc_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 136648 nodes
#
# === Step 2/24963 ===
# Block size: 2030
# Subgraph nodes: 2030, Expected block nodes: 2030
#   Found 1915 SCCs in block
# Total SCCs found: 1915
# Topologically sorted SCCs: 1915
# New block order length: 2030
# ✅ All 2030 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 2:
#    block index range: [5:2035]
#    sample prev_order for first 5 block nodes: [7607, 7608, 7609, 7610, 7611]
#    computed base_rank = 7607
#    new_block_order sample first5: ['720575940626352176', '720575940625413763', '720575940632852817', '720575940633336476', '720575940626310686'], last5: ['720575940613522413', '720575940624123174', '720575940628832516', '720575940630569413', '720575940622444780']
# Step 2: New FW = 35462925.00, Existing FW = 35462925.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 136648 nodes by SCC topology and saved to ../datasets/connectome_scc_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 136648 nodes
#
# === Step 3/24963 ===
# Block size: 2030
# Subgraph nodes: 2030, Expected block nodes: 2030
#   Found 1918 SCCs in block
# Total SCCs found: 1918
# Topologically sorted SCCs: 1918
# New block order length: 2030
# ✅ All 2030 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 3:
#    block index range: [10:2040]
#    sample prev_order for first 5 block nodes: [7612, 7613, 7614, 7615, 7616]
#    computed base_rank = 7612
#    new_block_order sample first5: ['720575940626352176', '720575940625413763', '720575940632852817', '720575940633336476', '720575940626310686'], last5: ['720575940613522413', '720575940624123174', '720575940628832516', '720575940630569413', '720575940622444780']
# Step 3: New FW = 35462925.00, Existing FW = 35462925.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_141506/951793511.py in <module>
# ----> 1 refine_largest_scc_toposorted_blocks()
#
# /tmp/ipykernel_141506/510774110.py in refine_largest_scc_toposorted_blocks(sz, bias, gf, edge_path, output_path)
#      70             edge_csv=edge_path,
#      71             ranking_csv=output_path,
# ---> 72             output_csv=output_path
#      73         )
#      74
#
# /tmp/ipykernel_141506/70510940.py in reorder_by_scc_topology(edge_csv, ranking_csv, output_csv)
#      30
#      31     G = nx.DiGraph()
# ---> 32     G.add_weighted_edges_from(edges)
#      33
#      34     # --- 2. Compute SCCs and condensation DAG ---
#
# ~/.conda/envs/GNNRank/lib/python3.7/site-packages/networkx/classes/graph.py in add_weighted_edges_from(self, ebunch_to_add, weight, **attr)
#     986         >>> G.add_weighted_edges_from([(0, 1, 3.0), (1, 2, 7.5)])
#     987         """
# --> 988         self.add_edges_from(((u, v, {weight: d}) for u, v, d in ebunch_to_add), **attr)
#     989
#     990     def remove_edge(self, u, v):
#
# ~/.conda/envs/GNNRank/lib/python3.7/site-packages/networkx/classes/digraph.py in add_edges_from(self, ebunch_to_add, **attr)
#     675         """
#     676         for e in ebunch_to_add:
# --> 677             ne = len(e)
#     678             if ne == 3:
#     679                 u, v, dd = e
#
# KeyboardInterrupt:

# %%
import os
import json
import logging
import pandas as pd
# !pip install -q scikit-optimize

from itertools import permutations
from skopt import gp_minimize
from skopt.space import Integer
from skopt.utils import use_named_args



logging.basicConfig(level=logging.INFO)

EDGE_PATH = "/content/drive/MyDrive/ibm01.csv"
RANKING_PATH = "/content/drive/MyDrive/ibm01_ranking.csv"
HYPERPARAM_FILE = "/content/drive/MyDrive/ibm01_hyperparams.json"

# Define search space for sz, bias_factor, gf_factor
sz_space = Integer(1000, 10000, name='sz')
bias_factor_space = Integer(5, 20, name='bias_factor')
gf_factor_space = Integer(30, 100, name='gf_factor')
search_space = [sz_space, bias_factor_space, gf_factor_space]


def compute_forward_weight(edges, order_map):
    return sum(
        w for u, v, w in edges
        if order_map.get(u, float('inf')) < order_map.get(v, float('inf'))
    )


def evaluate_forward_weight(sz, bias, gf):
    edges, node_to_index, index_to_node = read_graph(EDGE_PATH)
    initial_scores = load_initial_scores(RANKING_PATH, node_to_index)
    initial_fw = compute_forward_weight(edges, initial_scores)

    refine_largest_scc_toposorted_blocks(sz=sz, bias=bias, gf=gf,edge_path=EDGE_PATH,output_path=RANKING_PATH)

    new_scores = load_initial_scores(RANKING_PATH, node_to_index)
    new_fw = compute_forward_weight(edges, new_scores)

    improvement = new_fw - initial_fw
    logging.info(f"Evaluated sz={sz}, bias={bias}, gf={gf} => improvement={improvement}")
    return improvement

@use_named_args(search_space)
def objective(**params):
    sz = params['sz']
    bias = max(1, sz // params['bias_factor'])
    gf = max(1, sz // params['gf_factor'])
    return -evaluate_forward_weight(sz, bias, gf)


def load_previous_hyperparams():
    if os.path.exists(HYPERPARAM_FILE):
        with open(HYPERPARAM_FILE) as f:
            data = json.load(f)
            logging.info(f"Loaded previous hyperparams: {data}")
            return data
    return None


def save_hyperparams(sz, bias_factor, gf_factor, improvement):
    data = {
        'sz': sz,
        'bias_factor': bias_factor,
        'gf_factor': gf_factor,
        'improvement': improvement
    }
    with open(HYPERPARAM_FILE, 'w') as f:
        json.dump(data, f, indent=2)
    logging.info(f"Saved hyperparams: {data}")


def bayesian_tune_refinement(n_calls=30):
    prev = load_previous_hyperparams()
    if prev:
        # Seed optimizer with previous best
        x0 = [prev['sz'], prev['bias_factor'], prev['gf_factor']]
        y0 = [-prev['improvement']]
        result = gp_minimize(
            objective,
            search_space,
            acq_func='EI',
            n_calls=n_calls,
            x0=[x0],
            y0=y0,
            random_state=42
        )
    else:
        result = gp_minimize(
            objective,
            search_space,
            acq_func='EI',
            n_calls=n_calls,
            random_state=42
        )

    best_sz, best_bias_fact, best_gf_fact = result.x
    best_bias = max(1, best_sz // best_bias_fact)
    best_gf = max(1, best_sz // best_gf_fact)
    best_improvement = -result.fun

    save_hyperparams(best_sz, best_bias_fact, best_gf_fact, best_improvement)

    logging.info(f"Best found: sz={best_sz}, bias={best_bias}, gf={best_gf}, improvement={best_improvement}")
    refine_largest_scc_toposorted_blocks(sz=best_sz, bias=best_bias, gf=best_gf,edge_path=EDGE_PATH,output_path=RANKING_PATH)

if __name__ == '__main__':
    bayesian_tune_refinement(n_calls=3000)
# Out:
# Streaming output truncated to the last 5000 lines.
#    new_block_order sample first5: ['8484', '477', '4827', '4045', '8880'], last5: ['11436', '11072', '7782', '9427', '4537']
# Step 424: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 425/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 684 SCCs in block
# Total SCCs found: 684
# Topologically sorted SCCs: 684
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 425:
#    block index range: [4723:5903]
#    sample prev_order for first 5 block nodes: [4921, 4922, 4923, 4924, 4925]
#    computed base_rank = 4921
#    new_block_order sample first5: ['8484', '477', '4827', '4045', '8880'], last5: ['10757', '2639', '4740', '5185', '3378']
# Step 425: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 426/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 678 SCCs in block
# Total SCCs found: 678
# Topologically sorted SCCs: 678
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 426:
#    block index range: [4734:5914]
#    sample prev_order for first 5 block nodes: [4932, 4933, 4934, 4935, 4936]
#    computed base_rank = 4932
#    new_block_order sample first5: ['8484', '477', '4827', '4045', '8880'], last5: ['4499', '9507', '11499', '12717', '10029']
# Step 426: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 427/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 598 SCCs in block
# Total SCCs found: 598
# Topologically sorted SCCs: 598
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 427:
#    block index range: [4745:5925]
#    sample prev_order for first 5 block nodes: [4943, 4944, 4945, 4946, 4947]
#    computed base_rank = 4943
#    new_block_order sample first5: ['8484', '477', '4827', '4045', '8880'], last5: ['5760', '10834', '27', '12518', '5950']
# Step 427: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 428/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 577 SCCs in block
# Total SCCs found: 577
# Topologically sorted SCCs: 577
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 428:
#    block index range: [4756:5936]
#    sample prev_order for first 5 block nodes: [4954, 4955, 4956, 4957, 4958]
#    computed base_rank = 4954
#    new_block_order sample first5: ['8484', '477', '4827', '4045', '8880'], last5: ['12584', '4939', '4127', '2651', '939']
# Step 428: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 429/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 573 SCCs in block
# Total SCCs found: 573
# Topologically sorted SCCs: 573
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 429:
#    block index range: [4767:5947]
#    sample prev_order for first 5 block nodes: [4965, 4966, 4967, 4968, 4969]
#    computed base_rank = 4965
#    new_block_order sample first5: ['8484', '477', '4827', '4045', '8880'], last5: ['12538', '2492', '981', '9404', '10715']
# Step 429: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 430/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 593 SCCs in block
# Total SCCs found: 593
# Topologically sorted SCCs: 593
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 430:
#    block index range: [4778:5958]
#    sample prev_order for first 5 block nodes: [4976, 4977, 4978, 4979, 4980]
#    computed base_rank = 4976
#    new_block_order sample first5: ['8880', '5387', '3174', '5404', '3161'], last5: ['4434', '61', '12574', '6035', '8557']
# Step 430: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 431/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 612 SCCs in block
# Total SCCs found: 612
# Topologically sorted SCCs: 612
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 431:
#    block index range: [4789:5969]
#    sample prev_order for first 5 block nodes: [4987, 4988, 4989, 4990, 4991]
#    computed base_rank = 4987
#    new_block_order sample first5: ['5008', '2385', '4985', '9690', '3336'], last5: ['12584', '4939', '4127', '2651', '939']
# Step 431: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 432/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 602 SCCs in block
# Total SCCs found: 602
# Topologically sorted SCCs: 602
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 432:
#    block index range: [4800:5980]
#    sample prev_order for first 5 block nodes: [4998, 4999, 5000, 5001, 5002]
#    computed base_rank = 4998
#    new_block_order sample first5: ['5008', '2385', '8388', '5510', '11054'], last5: ['4127', '2651', '11443', '939', '8596']
# Step 432: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 433/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 598 SCCs in block
# Total SCCs found: 598
# Topologically sorted SCCs: 598
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 433:
#    block index range: [4811:5991]
#    sample prev_order for first 5 block nodes: [5009, 5010, 5011, 5012, 5013]
#    computed base_rank = 5009
#    new_block_order sample first5: ['5008', '7897', '3963', '2385', '2700'], last5: ['8006', '6759', '939', '12398', '8596']
# Step 433: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 434/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 598 SCCs in block
# Total SCCs found: 598
# Topologically sorted SCCs: 598
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 434:
#    block index range: [4822:6002]
#    sample prev_order for first 5 block nodes: [5020, 5021, 5022, 5023, 5024]
#    computed base_rank = 5020
#    new_block_order sample first5: ['5008', '7897', '3963', '2385', '10974'], last5: ['6759', '939', '12398', '4048', '8596']
# Step 434: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 435/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 598 SCCs in block
# Total SCCs found: 598
# Topologically sorted SCCs: 598
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 435:
#    block index range: [4833:6013]
#    sample prev_order for first 5 block nodes: [5031, 5032, 5033, 5034, 5035]
#    computed base_rank = 5031
#    new_block_order sample first5: ['5008', '3259', '526', '9531', '7897'], last5: ['3689', '11961', '10711', '11886', '5468']
# Step 435: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 436/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 595 SCCs in block
# Total SCCs found: 595
# Topologically sorted SCCs: 595
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 436:
#    block index range: [4844:6024]
#    sample prev_order for first 5 block nodes: [5042, 5043, 5044, 5045, 5046]
#    computed base_rank = 5042
#    new_block_order sample first5: ['5008', '3259', '526', '9531', '7897'], last5: ['10711', '11886', '5468', '754', '10672']
# Step 436: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 437/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 593 SCCs in block
# Total SCCs found: 593
# Topologically sorted SCCs: 593
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 437:
#    block index range: [4855:6035]
#    sample prev_order for first 5 block nodes: [5053, 5054, 5055, 5056, 5057]
#    computed base_rank = 5053
#    new_block_order sample first5: ['5008', '3259', '526', '9531', '7897'], last5: ['10672', '2400', '10043', '9274', '4185']
# Step 437: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 438/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 590 SCCs in block
# Total SCCs found: 590
# Topologically sorted SCCs: 590
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 438:
#    block index range: [4866:6046]
#    sample prev_order for first 5 block nodes: [5064, 5065, 5066, 5067, 5068]
#    computed base_rank = 5064
#    new_block_order sample first5: ['5008', '3259', '526', '9531', '7897'], last5: ['6048', '2354', '6242', '9274', '4185']
# Step 438: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 439/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 587 SCCs in block
# Total SCCs found: 587
# Topologically sorted SCCs: 587
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 439:
#    block index range: [4877:6057]
#    sample prev_order for first 5 block nodes: [5075, 5076, 5077, 5078, 5079]
#    computed base_rank = 5075
#    new_block_order sample first5: ['5008', '3259', '526', '9531', '7897'], last5: ['4185', '529', '9219', '8403', '11542']
# Step 439: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 440/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 587 SCCs in block
# Total SCCs found: 587
# Topologically sorted SCCs: 587
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 440:
#    block index range: [4888:6068]
#    sample prev_order for first 5 block nodes: [5086, 5087, 5088, 5089, 5090]
#    computed base_rank = 5086
#    new_block_order sample first5: ['5008', '3259', '526', '9531', '7897'], last5: ['9219', '8403', '5390', '11542', '2560']
# Step 440: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 441/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 586 SCCs in block
# Total SCCs found: 586
# Topologically sorted SCCs: 586
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 441:
#    block index range: [4899:6079]
#    sample prev_order for first 5 block nodes: [5097, 5098, 5099, 5100, 5101]
#    computed base_rank = 5097
#    new_block_order sample first5: ['5008', '3963', '12208', '2385', '4236'], last5: ['2560', '2554', '12087', '11542', '7727']
# Step 441: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 442/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 586 SCCs in block
# Total SCCs found: 586
# Topologically sorted SCCs: 586
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 442:
#    block index range: [4910:6090]
#    sample prev_order for first 5 block nodes: [5108, 5109, 5110, 5111, 5112]
#    computed base_rank = 5108
#    new_block_order sample first5: ['5008', '3963', '12208', '2385', '4236'], last5: ['5650', '9416', '5687', '11789', '7754']
# Step 442: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 443/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 587 SCCs in block
# Total SCCs found: 587
# Topologically sorted SCCs: 587
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 443:
#    block index range: [4921:6101]
#    sample prev_order for first 5 block nodes: [5119, 5120, 5121, 5122, 5123]
#    computed base_rank = 5119
#    new_block_order sample first5: ['5008', '3963', '12208', '2385', '4236'], last5: ['7113', '974', '1602', '2339', '3941']
# Step 443: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 444/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 584 SCCs in block
# Total SCCs found: 584
# Topologically sorted SCCs: 584
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 444:
#    block index range: [4932:6112]
#    sample prev_order for first 5 block nodes: [5130, 5131, 5132, 5133, 5134]
#    computed base_rank = 5130
#    new_block_order sample first5: ['5008', '3963', '12208', '2385', '4236'], last5: ['2339', '3941', '1609', '11937', '6854']
# Step 444: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 445/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 584 SCCs in block
# Total SCCs found: 584
# Topologically sorted SCCs: 584
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 445:
#    block index range: [4943:6123]
#    sample prev_order for first 5 block nodes: [5141, 5142, 5143, 5144, 5145]
#    computed base_rank = 5141
#    new_block_order sample first5: ['5008', '3963', '12208', '2385', '10974'], last5: ['3941', '1609', '11937', '6854', '8474']
# Step 445: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 446/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 581 SCCs in block
# Total SCCs found: 581
# Topologically sorted SCCs: 581
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 446:
#    block index range: [4954:6134]
#    sample prev_order for first 5 block nodes: [5152, 5153, 5154, 5155, 5156]
#    computed base_rank = 5152
#    new_block_order sample first5: ['5008', '3963', '12208', '2385', '10974'], last5: ['1609', '11937', '6854', '8474', '12466']
# Step 446: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 447/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 575 SCCs in block
# Total SCCs found: 575
# Topologically sorted SCCs: 575
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 447:
#    block index range: [4965:6145]
#    sample prev_order for first 5 block nodes: [5163, 5164, 5165, 5166, 5167]
#    computed base_rank = 5163
#    new_block_order sample first5: ['5008', '3963', '12208', '4303', '10974'], last5: ['6854', '11077', '8474', '12466', '12369']
# Step 447: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 448/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 575 SCCs in block
# Total SCCs found: 575
# Topologically sorted SCCs: 575
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 448:
#    block index range: [4976:6156]
#    sample prev_order for first 5 block nodes: [5174, 5175, 5176, 5177, 5178]
#    computed base_rank = 5174
#    new_block_order sample first5: ['5008', '3963', '3185', '12208', '4303'], last5: ['9608', '12466', '2684', '12369', '10265']
# Step 448: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 449/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 575 SCCs in block
# Total SCCs found: 575
# Topologically sorted SCCs: 575
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 449:
#    block index range: [4987:6167]
#    sample prev_order for first 5 block nodes: [5185, 5186, 5187, 5188, 5189]
#    computed base_rank = 5185
#    new_block_order sample first5: ['5008', '3185', '12208', '4303', '10974'], last5: ['10265', '6807', '11117', '12317', '5344']
# Step 449: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 450/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 575 SCCs in block
# Total SCCs found: 575
# Topologically sorted SCCs: 575
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 450:
#    block index range: [4998:6178]
#    sample prev_order for first 5 block nodes: [5196, 5197, 5198, 5199, 5200]
#    computed base_rank = 5196
#    new_block_order sample first5: ['5008', '3185', '4303', '7486', '12440'], last5: ['11067', '7299', '5788', '6794', '8250']
# Step 450: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 451/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 576 SCCs in block
# Total SCCs found: 576
# Topologically sorted SCCs: 576
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 451:
#    block index range: [5009:6189]
#    sample prev_order for first 5 block nodes: [5207, 5208, 5209, 5210, 5211]
#    computed base_rank = 5207
#    new_block_order sample first5: ['5008', '3185', '4303', '5420', '11369'], last5: ['4330', '9102', '8670', '10777', '10002']
# Step 451: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 452/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 576 SCCs in block
# Total SCCs found: 576
# Topologically sorted SCCs: 576
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 452:
#    block index range: [5020:6200]
#    sample prev_order for first 5 block nodes: [5218, 5219, 5220, 5221, 5222]
#    computed base_rank = 5218
#    new_block_order sample first5: ['5008', '3185', '5117', '11369', '4225'], last5: ['2965', '11029', '11182', '7871', '7141']
# Step 452: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 453/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 576 SCCs in block
# Total SCCs found: 576
# Topologically sorted SCCs: 576
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 453:
#    block index range: [5031:6211]
#    sample prev_order for first 5 block nodes: [5229, 5230, 5231, 5232, 5233]
#    computed base_rank = 5229
#    new_block_order sample first5: ['5008', '5117', '11369', '4225', '2242'], last5: ['10334', '10158', '10300', '9431', '10970']
# Step 453: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 454/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 576 SCCs in block
# Total SCCs found: 576
# Topologically sorted SCCs: 576
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 454:
#    block index range: [5042:6222]
#    sample prev_order for first 5 block nodes: [5240, 5241, 5242, 5243, 5244]
#    computed base_rank = 5240
#    new_block_order sample first5: ['5008', '11764', '5117', '8661', '11369'], last5: ['1812', '1518', '6494', '4587', '841']
# Step 454: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 455/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 578 SCCs in block
# Total SCCs found: 578
# Topologically sorted SCCs: 578
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 455:
#    block index range: [5053:6233]
#    sample prev_order for first 5 block nodes: [5251, 5252, 5253, 5254, 5255]
#    computed base_rank = 5251
#    new_block_order sample first5: ['5008', '11764', '8661', '11369', '4602'], last5: ['11990', '1716', '3281', '5906', '3219']
# Step 455: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 456/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 576 SCCs in block
# Total SCCs found: 576
# Topologically sorted SCCs: 576
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 456:
#    block index range: [5064:6244]
#    sample prev_order for first 5 block nodes: [5262, 5263, 5264, 5265, 5266]
#    computed base_rank = 5262
#    new_block_order sample first5: ['5008', '8661', '11369', '5643', '11900'], last5: ['9132', '959', '3803', '8153', '8539']
# Step 456: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 457/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 574 SCCs in block
# Total SCCs found: 574
# Topologically sorted SCCs: 574
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 457:
#    block index range: [5075:6255]
#    sample prev_order for first 5 block nodes: [5273, 5274, 5275, 5276, 5277]
#    computed base_rank = 5273
#    new_block_order sample first5: ['5008', '11369', '6865', '11165', '12296'], last5: ['8153', '8539', '1411', '6718', '10093']
# Step 457: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 458/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 575 SCCs in block
# Total SCCs found: 575
# Topologically sorted SCCs: 575
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 458:
#    block index range: [5086:6266]
#    sample prev_order for first 5 block nodes: [5284, 5285, 5286, 5287, 5288]
#    computed base_rank = 5284
#    new_block_order sample first5: ['5008', '11369', '2691', '641', '553'], last5: ['6718', '10093', '7580', '6710', '10125']
# Step 458: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 459/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 577 SCCs in block
# Total SCCs found: 577
# Topologically sorted SCCs: 577
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 459:
#    block index range: [5097:6277]
#    sample prev_order for first 5 block nodes: [5295, 5296, 5297, 5298, 5299]
#    computed base_rank = 5295
#    new_block_order sample first5: ['5008', '11369', '9547', '641', '553'], last5: ['6710', '10125', '9047', '5738', '6281']
# Step 459: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 460/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 581 SCCs in block
# Total SCCs found: 581
# Topologically sorted SCCs: 581
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 460:
#    block index range: [5108:6288]
#    sample prev_order for first 5 block nodes: [5306, 5307, 5308, 5309, 5310]
#    computed base_rank = 5306
#    new_block_order sample first5: ['5008', '4159', '10730', '11369', '332'], last5: ['6710', '10125', '9047', '5738', '6281']
# Step 460: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 461/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 586 SCCs in block
# Total SCCs found: 586
# Topologically sorted SCCs: 586
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 461:
#    block index range: [5119:6299]
#    sample prev_order for first 5 block nodes: [5317, 5318, 5319, 5320, 5321]
#    computed base_rank = 5317
#    new_block_order sample first5: ['5008', '5641', '9815', '11369', '10667'], last5: ['6710', '10125', '9047', '5738', '6281']
# Step 461: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 462/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 590 SCCs in block
# Total SCCs found: 590
# Topologically sorted SCCs: 590
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 462:
#    block index range: [5130:6310]
#    sample prev_order for first 5 block nodes: [5328, 5329, 5330, 5331, 5332]
#    computed base_rank = 5328
#    new_block_order sample first5: ['5008', '11369', '2873', '9874', '11609'], last5: ['9047', '5738', '6281', '11893', '1297']
# Step 462: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 463/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 596 SCCs in block
# Total SCCs found: 596
# Topologically sorted SCCs: 596
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 463:
#    block index range: [5141:6321]
#    sample prev_order for first 5 block nodes: [5339, 5340, 5341, 5342, 5343]
#    computed base_rank = 5339
#    new_block_order sample first5: ['5008', '11369', '641', '553', '12153'], last5: ['6281', '11893', '1297', '12156', '5619']
# Step 463: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 464/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 601 SCCs in block
# Total SCCs found: 601
# Topologically sorted SCCs: 601
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 464:
#    block index range: [5152:6332]
#    sample prev_order for first 5 block nodes: [5350, 5351, 5352, 5353, 5354]
#    computed base_rank = 5350
#    new_block_order sample first5: ['5008', '9762', '10428', '11369', '641'], last5: ['6281', '11893', '1297', '12156', '5619']
# Step 464: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 465/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 608 SCCs in block
# Total SCCs found: 608
# Topologically sorted SCCs: 608
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 465:
#    block index range: [5163:6343]
#    sample prev_order for first 5 block nodes: [5361, 5362, 5363, 5364, 5365]
#    computed base_rank = 5361
#    new_block_order sample first5: ['5008', '11369', '9294', '641', '553'], last5: ['6281', '11893', '1297', '12156', '5619']
# Step 465: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 466/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 612 SCCs in block
# Total SCCs found: 612
# Topologically sorted SCCs: 612
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 466:
#    block index range: [5174:6354]
#    sample prev_order for first 5 block nodes: [5372, 5373, 5374, 5375, 5376]
#    computed base_rank = 5372
#    new_block_order sample first5: ['5008', '10069', '4646', '11369', '8982'], last5: ['906', '1506', '3641', '8717', '5734']
# Step 466: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 467/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 616 SCCs in block
# Total SCCs found: 616
# Topologically sorted SCCs: 616
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 467:
#    block index range: [5185:6365]
#    sample prev_order for first 5 block nodes: [5383, 5384, 5385, 5386, 5387]
#    computed base_rank = 5383
#    new_block_order sample first5: ['5008', '2830', '7294', '330', '11369'], last5: ['4863', '8360', '11155', '7575', '5683']
# Step 467: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 468/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 621 SCCs in block
# Total SCCs found: 621
# Topologically sorted SCCs: 621
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 468:
#    block index range: [5196:6376]
#    sample prev_order for first 5 block nodes: [5394, 5395, 5396, 5397, 5398]
#    computed base_rank = 5394
#    new_block_order sample first5: ['5008', '2880', '4402', '1876', '9730'], last5: ['5683', '5552', '3034', '9790', '1881']
# Step 468: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 469/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 625 SCCs in block
# Total SCCs found: 625
# Topologically sorted SCCs: 625
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 469:
#    block index range: [5207:6387]
#    sample prev_order for first 5 block nodes: [5405, 5406, 5407, 5408, 5409]
#    computed base_rank = 5405
#    new_block_order sample first5: ['5008', '1276', '7705', '2958', '11369'], last5: ['8565', '6333', '3756', '2181', '7863']
# Step 469: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 470/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 628 SCCs in block
# Total SCCs found: 628
# Topologically sorted SCCs: 628
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 470:
#    block index range: [5218:6398]
#    sample prev_order for first 5 block nodes: [5416, 5417, 5418, 5419, 5420]
#    computed base_rank = 5416
#    new_block_order sample first5: ['5008', '9182', '326', '1325', '11369'], last5: ['7863', '4717', '8986', '9602', '7846']
# Step 470: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 471/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 631 SCCs in block
# Total SCCs found: 631
# Topologically sorted SCCs: 631
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 471:
#    block index range: [5229:6409]
#    sample prev_order for first 5 block nodes: [5427, 5428, 5429, 5430, 5431]
#    computed base_rank = 5427
#    new_block_order sample first5: ['5008', '1392', '6028', '370', '11369'], last5: ['7822', '7846', '6103', '7553', '6085']
# Step 471: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 472/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 637 SCCs in block
# Total SCCs found: 637
# Topologically sorted SCCs: 637
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 472:
#    block index range: [5240:6420]
#    sample prev_order for first 5 block nodes: [5438, 5439, 5440, 5441, 5442]
#    computed base_rank = 5438
#    new_block_order sample first5: ['5008', '6869', '11369', '12048', '6077'], last5: ['4959', '4201', '11598', '6218', '3425']
# Step 472: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 473/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 642 SCCs in block
# Total SCCs found: 642
# Topologically sorted SCCs: 642
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 473:
#    block index range: [5251:6431]
#    sample prev_order for first 5 block nodes: [5449, 5450, 5451, 5452, 5453]
#    computed base_rank = 5449
#    new_block_order sample first5: ['5008', '11369', '641', '553', '12153'], last5: ['11821', '3351', '3594', '5157', '4110']
# Step 473: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 474/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 649 SCCs in block
# Total SCCs found: 649
# Topologically sorted SCCs: 649
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 474:
#    block index range: [5262:6442]
#    sample prev_order for first 5 block nodes: [5460, 5461, 5462, 5463, 5464]
#    computed base_rank = 5460
#    new_block_order sample first5: ['5008', '11369', '1661', '641', '553'], last5: ['2495', '4489', '3287', '436', '4688']
# Step 474: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 475/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 655 SCCs in block
# Total SCCs found: 655
# Topologically sorted SCCs: 655
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 475:
#    block index range: [5273:6453]
#    sample prev_order for first 5 block nodes: [5471, 5472, 5473, 5474, 5475]
#    computed base_rank = 5471
#    new_block_order sample first5: ['5008', '1636', '11369', '7206', '641'], last5: ['1944', '3290', '1874', '12203', '3516']
# Step 475: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 476/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 660 SCCs in block
# Total SCCs found: 660
# Topologically sorted SCCs: 660
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 476:
#    block index range: [5284:6464]
#    sample prev_order for first 5 block nodes: [5482, 5483, 5484, 5485, 5486]
#    computed base_rank = 5482
#    new_block_order sample first5: ['5008', '11369', '3583', '8677', '9993'], last5: ['11055', '11969', '7372', '1046', '10277']
# Step 476: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 477/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 666 SCCs in block
# Total SCCs found: 666
# Topologically sorted SCCs: 666
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 477:
#    block index range: [5295:6475]
#    sample prev_order for first 5 block nodes: [5493, 5494, 5495, 5496, 5497]
#    computed base_rank = 5493
#    new_block_order sample first5: ['5008', '123', '11369', '7206', '641'], last5: ['11328', '7301', '9197', '4364', '10374']
# Step 477: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 478/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 670 SCCs in block
# Total SCCs found: 670
# Topologically sorted SCCs: 670
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 478:
#    block index range: [5306:6486]
#    sample prev_order for first 5 block nodes: [5504, 5505, 5506, 5507, 5508]
#    computed base_rank = 5504
#    new_block_order sample first5: ['5008', '11369', '7206', '1379', '641'], last5: ['11799', '3340', '2716', '11842', '12021']
# Step 478: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 479/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 673 SCCs in block
# Total SCCs found: 673
# Topologically sorted SCCs: 673
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 479:
#    block index range: [5317:6497]
#    sample prev_order for first 5 block nodes: [5515, 5516, 5517, 5518, 5519]
#    computed base_rank = 5515
#    new_block_order sample first5: ['5008', '11369', '4145', '11992', '4568'], last5: ['3181', '8413', '8695', '9593', '11175']
# Step 479: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 480/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 676 SCCs in block
# Total SCCs found: 676
# Topologically sorted SCCs: 676
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 480:
#    block index range: [5328:6508]
#    sample prev_order for first 5 block nodes: [5526, 5527, 5528, 5529, 5530]
#    computed base_rank = 5526
#    new_block_order sample first5: ['5008', '9929', '11369', '7206', '11514'], last5: ['2375', '3852', '8146', '367', '11637']
# Step 480: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 481/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 676 SCCs in block
# Total SCCs found: 676
# Topologically sorted SCCs: 676
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 481:
#    block index range: [5339:6519]
#    sample prev_order for first 5 block nodes: [5537, 5538, 5539, 5540, 5541]
#    computed base_rank = 5537
#    new_block_order sample first5: ['5008', '4767', '11369', '7206', '10031'], last5: ['2852', '3349', '7639', '12099', '12230']
# Step 481: New FW = 34277.00, Existing FW = 34277.00
# ...
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 675/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 471 SCCs in block
# Total SCCs found: 471
# Topologically sorted SCCs: 471
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 675:
#    block index range: [7473:8653]
#    sample prev_order for first 5 block nodes: [7671, 7672, 7673, 7674, 7675]
#    computed base_rank = 7671
#    new_block_order sample first5: ['5061', '4503', '2075', '12599', '1629'], last5: ['1426', '4763', '11180', '8181', '2978']
# Step 675: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 676/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 475 SCCs in block
# Total SCCs found: 475
# Topologically sorted SCCs: 475
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 676:
#    block index range: [7484:8664]
#    sample prev_order for first 5 block nodes: [7682, 7683, 7684, 7685, 7686]
#    computed base_rank = 7682
#    new_block_order sample first5: ['5061', '4503', '2075', '12599', '1629'], last5: ['9610', '11962', '11180', '8181', '2978']
# Step 676: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 677/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 475 SCCs in block
# Total SCCs found: 475
# Topologically sorted SCCs: 475
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 677:
#    block index range: [7495:8675]
#    sample prev_order for first 5 block nodes: [7693, 7694, 7695, 7696, 7697]
#    computed base_rank = 7693
#    new_block_order sample first5: ['5061', '4503', '2075', '12599', '1629'], last5: ['11962', '1865', '11180', '8181', '2978']
# Step 677: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 678/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 472 SCCs in block
# Total SCCs found: 472
# Topologically sorted SCCs: 472
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 678:
#    block index range: [7506:8686]
#    sample prev_order for first 5 block nodes: [7704, 7705, 7706, 7707, 7708]
#    computed base_rank = 7704
#    new_block_order sample first5: ['5061', '4503', '2075', '12599', '1629'], last5: ['11962', '1865', '11180', '8181', '2978']
# Step 678: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 679/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 489 SCCs in block
# Total SCCs found: 489
# Topologically sorted SCCs: 489
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 679:
#    block index range: [7517:8697]
#    sample prev_order for first 5 block nodes: [7715, 7716, 7717, 7718, 7719]
#    computed base_rank = 7715
#    new_block_order sample first5: ['6375', '5061', '4503', '4342', '2075'], last5: ['11962', '1865', '11180', '8181', '2978']
# Step 679: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 680/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 540 SCCs in block
# Total SCCs found: 540
# Topologically sorted SCCs: 540
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 680:
#    block index range: [7528:8708]
#    sample prev_order for first 5 block nodes: [7726, 7727, 7728, 7729, 7730]
#    computed base_rank = 7726
#    new_block_order sample first5: ['6375', '5061', '4503', '4342', '2075'], last5: ['3723', '10752', '11702', '6734', '9149']
# Step 680: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 681/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 551 SCCs in block
# Total SCCs found: 551
# Topologically sorted SCCs: 551
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 681:
#    block index range: [7539:8719]
#    sample prev_order for first 5 block nodes: [7737, 7738, 7739, 7740, 7741]
#    computed base_rank = 7737
#    new_block_order sample first5: ['6375', '5061', '4503', '4342', '2075'], last5: ['3723', '10752', '11702', '6734', '9149']
# Step 681: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 682/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 564 SCCs in block
# Total SCCs found: 564
# Topologically sorted SCCs: 564
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 682:
#    block index range: [7550:8730]
#    sample prev_order for first 5 block nodes: [7748, 7749, 7750, 7751, 7752]
#    computed base_rank = 7748
#    new_block_order sample first5: ['6375', '5061', '4503', '4342', '2075'], last5: ['11702', '6734', '9149', '12152', '10516']
# Step 682: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 683/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 558 SCCs in block
# Total SCCs found: 558
# Topologically sorted SCCs: 558
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 683:
#    block index range: [7561:8741]
#    sample prev_order for first 5 block nodes: [7759, 7760, 7761, 7762, 7763]
#    computed base_rank = 7759
#    new_block_order sample first5: ['6375', '5061', '4503', '4342', '2075'], last5: ['9149', '1921', '2561', '12152', '10516']
# Step 683: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 684/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 554 SCCs in block
# Total SCCs found: 554
# Topologically sorted SCCs: 554
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 684:
#    block index range: [7572:8752]
#    sample prev_order for first 5 block nodes: [7770, 7771, 7772, 7773, 7774]
#    computed base_rank = 7770
#    new_block_order sample first5: ['6375', '5061', '4503', '4342', '2075'], last5: ['9149', '1921', '2561', '12152', '10516']
# Step 684: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 685/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 554 SCCs in block
# Total SCCs found: 554
# Topologically sorted SCCs: 554
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 685:
#    block index range: [7583:8763]
#    sample prev_order for first 5 block nodes: [7781, 7782, 7783, 7784, 7785]
#    computed base_rank = 7781
#    new_block_order sample first5: ['5061', '4503', '2075', '12599', '1629'], last5: ['9149', '1921', '2561', '12152', '10516']
# Step 685: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 686/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 554 SCCs in block
# Total SCCs found: 554
# Topologically sorted SCCs: 554
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 686:
#    block index range: [7594:8774]
#    sample prev_order for first 5 block nodes: [7792, 7793, 7794, 7795, 7796]
#    computed base_rank = 7792
#    new_block_order sample first5: ['5061', '4503', '2075', '12599', '1629'], last5: ['9149', '1921', '2561', '12152', '10516']
# Step 686: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv
# 📥 Reading ranking CSV...
# ✅ Loaded ranking for 12752 nodes
#
# === Step 687/927 ===
# Block size: 1180
# Subgraph nodes: 1180, Expected block nodes: 1180
#   Found 564 SCCs in block
# Total SCCs found: 564
# Topologically sorted SCCs: 564
# New block order length: 1180
# ✅ All 1180 nodes successfully added to new_block_order.
# 🗂️  Reassigning ranks for Step 687:
#    block index range: [7605:8785]
#    sample prev_order for first 5 block nodes: [7803, 7804, 7805, 7806, 7807]
#    computed base_rank = 7803
#    new_block_order sample first5: ['5061', '4503', '2075', '12599', '1629'], last5: ['9149', '1921', '2561', '12152', '10516']
# Step 687: New FW = 34277.00, Existing FW = 34277.00
# ⏭️  No strict improvement in either direction. Keeping current ranking in memory.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-344214218> in <cell line: 0>()
#     110
#     111 if __name__ == '__main__':
# --> 112     bayesian_tune_refinement(n_calls=3000)
#
# <ipython-input-11-344214218> in bayesian_tune_refinement(n_calls)
#      91         )
#      92     else:
# ---> 93         result = gp_minimize(
#      94             objective,
#      95             search_space,
#
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size, space_constraint)
#     279         )
#     280
# --> 281     return base_minimize(
#     282         func,
#     283         space,
#
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/base.py in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size, space_constraint)
#     330     for _ in range(n_calls):
#     331         next_x = optimizer.ask()
# --> 332         next_y = func(next_x)
#     333         result = optimizer.tell(next_x, next_y)
#     334         result.specs = specs
#
# /usr/local/lib/python3.11/dist-packages/skopt/utils.py in wrapper(x)
#     777
#     778             # Call the wrapped objective function with the named arguments.
# --> 779             objective_value = func(**arg_dict)
#     780
#     781             return objective_value
#
# <ipython-input-11-344214218> in objective(**params)
#      51     bias = max(1, sz // params['bias_factor'])
#      52     gf = max(1, sz // params['gf_factor'])
# ---> 53     return -evaluate_forward_weight(sz, bias, gf)
#      54
#      55
#
# <ipython-input-11-344214218> in evaluate_forward_weight(sz, bias, gf)
#      37     initial_fw = compute_forward_weight(edges, initial_scores)
#      38
# ---> 39     refine_largest_scc_toposorted_blocks(sz=sz, bias=bias, gf=gf,edge_path=EDGE_PATH,output_path=RANKING_PATH)
#      40
#      41     new_scores = load_initial_scores(RANKING_PATH, node_to_index)
#
# <ipython-input-8-3702033207> in refine_largest_scc_toposorted_blocks(sz, bias, gf, edge_path, output_path)
#      67
#      68         # 3) Now do the full‐graph SCC reorder (if you still want it every time)
# ---> 69         reorder_by_scc_topology(
#      70             edge_csv=edge_path,
#      71             ranking_csv=output_path,
#
# <ipython-input-10-474251289> in reorder_by_scc_topology(edge_csv, ranking_csv, output_csv)
#      15
#      16     # --- 1. Load graph and initial ranking ---
# ---> 17     df_e = pd.read_csv(edge_csv)
#      18     df_e.rename(columns={
#      19         'Source Node  ID':'source',
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/ibm01.csv'

# %%
reorder_by_scc_topology(
    edge_csv="/content/drive/MyDrive/ibm01.csv",
    ranking_csv="/content/drive/MyDrive/ibm01_ranking.csv",
    output_csv="/content/drive/MyDrive/ibm01_ranking.csv"
)
# Out:
# Reordered 12752 nodes by SCC topology and saved to /content/drive/MyDrive/ibm01_ranking.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
import numpy as np

def read_graph(path):
    df = pd.read_csv(path)
    df.rename(columns={
        'Source Node  ID': 'source',
        'Target Node ID': 'target',
        'Edge Weight': 'weight'
    }, inplace=True)
    df['source'] = df['source'].astype(str).str.strip()
    df['target'] = df['target'].astype(str).str.strip()
    nodes = sorted(set(df['source']).union(df['target']))
    node_to_index = {node: i for i, node in enumerate(nodes)}
    index_to_node = {i: node for node, i in node_to_index.items()}
    edges_indexed = [
        (node_to_index[src], node_to_index[tgt], float(w))
        for src, tgt, w in df[['source', 'target', 'weight']].values
    ]
    return edges_indexed, node_to_index, index_to_node

def load_initial_scores(path, node_to_index):
    df = pd.read_csv(path)
    df['Node ID'] = df['Node ID'].astype(str).str.strip()
    return {
        node_to_index[row['Node ID']]: int(row['Order'])
        for _, row in df.iterrows()
        if row['Node ID'] in node_to_index
    }

def analyze_back_edges(edges_indexed, scores, index_to_node, label="Ranking"):
    length_counts = defaultdict(int)
    back_lengths = []
    back_weights = []

    for u, v, w in edges_indexed:
        ru, rv = scores[u], scores[v]
        if ru > rv:
            length = ru - rv
            length_counts[length] += 1
            back_lengths.append(length)
            back_weights.append(w)

    count = len(back_lengths)
    avg_length = np.mean(back_lengths) if back_lengths else 0
    std_length = np.std(back_lengths) if back_lengths else 0
    min_length = min(back_lengths) if back_lengths else 0
    max_length = max(back_lengths) if back_lengths else 0

    total_back_weight = sum(back_weights)
    avg_back_weight = np.mean(back_weights) if back_weights else 0
    std_back_weight = np.std(back_weights) if back_weights else 0

    print(f"\n--- {label} ---")
    print(f"🔍 Number of back edges: {count}")
    print(f"📏 Back edge length stats: min={min_length}, max={max_length}, avg={avg_length:.2f}, std={std_length:.2f}")
    print(f"⚖️  Back edge weight stats: sum={total_back_weight:.2f}, avg={avg_back_weight:.2f}, std={std_back_weight:.2f}")

    cumulative = {}
    total = 0
    for i in range(1, max_length + 1):
        total += length_counts[i]
        cumulative[i] = total

    return count, length_counts, cumulative


def compute_forward_weight(edges_indexed, scores):
    fw = sum(w for u, v, w in edges_indexed if scores[u] < scores[v])
    total = sum(w for _, _, w in edges_indexed)
    return fw, total

def plot_histogram_and_cumulative(counts_db, cum_db, counts_ours, cum_ours):
    max_len = max(
        max(counts_db.keys(), default=0),
        max(counts_ours.keys(), default=0),
        2000
    )
    x_vals = list(range(1, max_len + 1))
    hist_db = [counts_db.get(i, 0) for i in x_vals]
    hist_ours = [counts_ours.get(i, 0) for i in x_vals]

    last_cum_db = 0
    cum_vals_db = []
    for i in x_vals:
        last_cum_db = cum_db.get(i, last_cum_db)
        cum_vals_db.append(last_cum_db)

    last_cum_ours = 0
    cum_vals_ours = []
    for i in x_vals:
        last_cum_ours = cum_ours.get(i, last_cum_ours)
        cum_vals_ours.append(last_cum_ours)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(x_vals, hist_db, label="BA-CD", alpha=0.7)
    plt.plot(x_vals, hist_ours, label="Ours", alpha=0.7)
    plt.yscale('log')
    plt.title("Back Edge Length Histogram")
    plt.xlabel("Back edge length (Δ rank)")
    plt.ylabel("Count (log scale)")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(x_vals, cum_vals_db, label="BA-CD")
    plt.plot(x_vals, cum_vals_ours, label="Ours")
    plt.title("Cumulative Back Edge Count")
    plt.xlabel("Back edge length ≤ i")
    plt.ylabel("Cumulative count")
    plt.legend()

    plt.tight_layout()
    plt.show()


# === File Paths ===
graph_path = "/content/drive/MyDrive/connectome_graph.csv"
ours_path = "/content/drive/MyDrive/35461047-Soroush-Ioannis-advancedimprove.csv"
db_path = "/content/drive/MyDrive/DB_challenge.csv"

# === Execution ===
edges_indexed, node_to_index, index_to_node = read_graph(graph_path)
scores_ours = load_initial_scores(ours_path, node_to_index)
scores_db = load_initial_scores(db_path, node_to_index)

count_db, counts_db, cum_db = analyze_back_edges(edges_indexed, scores_db, index_to_node, label="BA-CD's Ranking")
count_ours, counts_ours, cum_ours = analyze_back_edges(edges_indexed, scores_ours, index_to_node, label="Our Ranking")


fw_db, total_db = compute_forward_weight(edges_indexed, scores_db)
fw_ours, total_ours = compute_forward_weight(edges_indexed, scores_ours)

print("\n📏 Forward edge weight comparison:")
print(f"     BA-CD's forward weight:   {fw_db:.2f} / {total_db:.2f} = {fw_db / total_db:.4f}")
print(f"     Ours forward weight:   {fw_ours:.2f} / {total_ours:.2f} = {fw_ours / total_ours:.4f}")

plot_histogram_and_cumulative(counts_db, cum_db, counts_ours, cum_ours)
# Out:
# --- BA-CD's Ranking ---
# 🔍 Number of back edges: 1157173
# 📏 Back edge length stats: min=1, max=136410, avg=20449.85, std=24081.19
# ⚖️  Back edge weight stats: sum=6452875.00, avg=5.58, std=8.91
#
# --- Our Ranking ---
# 🔍 Number of back edges: 1156812
# 📏 Back edge length stats: min=1, max=126650, avg=20536.34, std=24542.31
# ⚖️  Back edge weight stats: sum=6449216.00, avg=5.57, std=8.90
#
# 📏 Forward edge weight comparison:
#      BA-CD's forward weight:   35459266.00 / 41912141.00 = 0.8460
#      Ours forward weight:   35462925.00 / 41912141.00 = 0.8461

# %%
import os
import pandas as pd
import networkx as nx
from itertools import permutations

def read_graph(csv_path):
    print("📥 Reading graph CSV...")
    df = pd.read_csv(csv_path)
    df.rename(columns={
        'Source Node  ID': 'source',
        'Target Node ID': 'target',
        'Edge Weight': 'weight'
    }, inplace=True)
    df['source'] = df['source'].astype(str)
    df['target'] = df['target'].astype(str)
    edges = list(df.itertuples(index=False, name=None))
    node_set = sorted(set(u for u, v, _ in edges).union(v for u, v, _ in edges))
    node_to_index = {node: i for i, node in enumerate(node_set)}
    index_to_node = {i: node for node, i in node_to_index.items()}
    edges_indexed = [(node_to_index[u], node_to_index[v], float(w)) for (u, v, w) in edges]
    print(f"✅ Graph loaded: {len(edges_indexed)} edges, {len(node_to_index)} nodes")
    return edges_indexed, node_to_index, index_to_node

def load_initial_scores(csv_path, node_to_index):
    print("📥 Reading ranking CSV...")
    df = pd.read_csv(csv_path)
    df['Node ID'] = df['Node ID'].astype(str).str.strip()
    rank_map = {row['Node ID']: row['Order'] for _, row in df.iterrows()}
    scores = {}
    for node_str, idx in node_to_index.items():
        if node_str in rank_map and idx not in scores:
            scores[idx] = int(rank_map[node_str])
    max_rank = max(scores.values(), default=0) + 1
    for node_str, idx in node_to_index.items():
        if idx not in scores:
            scores[idx] = max_rank
            max_rank += 1
    print(f"✅ Ranking loaded: {len(scores)} scores assigned")
    return scores

def compute_scc_optimized_ranking_with_filtered_backedges(edge_csv, ranking_csv):
    print("🚀 Starting SCC-based forward weight optimization with filtered back edges...")

    # Step 1: Read graph and initial scores
    edges, node_to_index, index_to_node = read_graph(edge_csv)
    scores = load_initial_scores(ranking_csv, node_to_index)

    print("🔧 Building directed graph...")
    G_full = nx.DiGraph()
    G_full.add_weighted_edges_from(edges)
    print(f"✅ Graph constructed: {G_full.number_of_nodes()} nodes, {G_full.number_of_edges()} edges")

    # Step 2: Identify backward edges and remove the lowest 50% by weight
    back_edges = [(u, v, w) for u, v, w in edges if scores[u] > scores[v]]
    back_edges_sorted = sorted(back_edges, key=lambda x: x[2])  # sort by weight ascending
    cutoff = len(back_edges_sorted) // 2
    back_edges_to_delete = set(back_edges_sorted[:cutoff])
    print(f"🔻 Removing {len(back_edges_to_delete)} low-weight backward edges before SCC analysis")

    edges_filtered = [e for e in edges if e not in back_edges_to_delete]

    # Step 3: Build filtered graph for SCC decomposition
    G_filtered = nx.DiGraph()
    G_filtered.add_weighted_edges_from(edges_filtered)

    print("🔍 Finding strongly connected components...")
    sccs = list(nx.strongly_connected_components(G_filtered))
    node_to_scc = {}
    for i, scc in enumerate(sccs):
        for node in scc:
            node_to_scc[node] = i
    print(f"✅ Found {len(sccs)} strongly connected components")

    print("🛠️ Building SCC DAG...")
    scc_dag = nx.DiGraph()
    for u, v, _ in edges_filtered:
        su, sv = node_to_scc[u], node_to_scc[v]
        if su != sv:
            scc_dag.add_edge(su, sv)
    print(f"✅ DAG: {scc_dag.number_of_nodes()} nodes, {scc_dag.number_of_edges()} edges")

    print("📏 Topologically sorting SCCs...")
    scc_order = list(nx.topological_sort(scc_dag))
    print("✅ SCC topological sort complete")

    print("⚙️ Ranking nodes...")
    node_order = {}
    current_rank = 0
    for scc_id in scc_order:
        component = list(sccs[scc_id])
        if len(component) > 1:
            print(f"🔹 SCC {scc_id} with {len(component)} nodes")

        if 1 < len(component) <= 9:
          print("   🔄 Trying all permutations to maximize internal forward weight...")
          initial_sorted = sorted(component, key=lambda n: scores.get(n, float('inf')))
          best_order = []
          max_internal_fw = -1

          # Build subgraph only once
          G_sub = G_full.subgraph(component).copy()

          for perm in permutations(initial_sorted):
              pos = {node: i for i, node in enumerate(perm)}
              fw = sum(
                  G_sub[u][v]['weight']
                  for u in G_sub.nodes
                  for v in G_sub[u]
                  if pos[u] < pos[v]
              )
              if fw > max_internal_fw:
                  max_internal_fw = fw
                  best_order = perm

          sorted_nodes = best_order
          print(f"   ✅ Best internal forward weight (reconsidering all edges): {max_internal_fw:.2f}")

        else:
           # print("   ➡️ Sorting by initial rank (too large to permute)")
            sorted_nodes = sorted(component, key=lambda n: scores.get(n, float('inf')))

        for node in sorted_nodes:
            node_order[node] = current_rank
            current_rank += 1

    # Compute forward weight of the initial ranking
    initial_fw = sum(
        w for u, v, w in edges if scores[u] < scores[v]
    )
    print(f"📊 Initial forward edge weight: {initial_fw:.2f}")

    # Compute forward weight of the optimized ranking
    new_fw = sum(
        w for u, v, w in edges if node_order.get(u, -1) < node_order.get(v, -1)
    )
    print(f"🎯 Total forward edge weight after optimization: {new_fw:.2f}")

    return new_fw
compute_scc_optimized_ranking_with_filtered_backedges(
    edge_csv="/content/drive/MyDrive/ibm01.csv",
    ranking_csv="/content/drive/MyDrive/ibm01_ranking.csv"
)
# Out:
# 🚀 Starting SCC-based forward weight optimization with filtered back edges...
# 📥 Reading graph CSV...
# ✅ Graph loaded: 36048 edges, 12752 nodes
# 📥 Reading ranking CSV...
# ✅ Ranking loaded: 12752 scores assigned
# 🔧 Building directed graph...
# ✅ Graph constructed: 12752 nodes, 36048 edges
# 🔻 Removing 1132 low-weight backward edges before SCC analysis
# 🔍 Finding strongly connected components...
# ✅ Found 4822 strongly connected components
# 🛠️ Building SCC DAG...
# ✅ DAG: 4822 nodes, 10798 edges
# 📏 Topologically sorting SCCs...
# ✅ SCC topological sort complete
# ⚙️ Ranking nodes...
# 🔹 SCC 4154 with 7836 nodes
# 🔹 SCC 2745 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2569 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2252 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2247 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2229 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2169 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2217 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2211 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2199 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2195 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2188 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2744 with 4 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 4.00
# 🔹 SCC 2652 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2184 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2159 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2239 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2235 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2223 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2242 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2164 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2166 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2742 with 4 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 3.00
# 🔹 SCC 2681 with 4 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 4.00
# 🔹 SCC 2651 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2741 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2650 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 953 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2589 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2588 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2677 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 950 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2587 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2598 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 2597 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 946 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 419 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 2583 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 418 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 2582 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 🔹 SCC 417 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 416 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 415 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 414 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 413 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 412 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 411 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 410 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 409 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 408 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 407 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 406 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 405 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 404 with 2 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 1.00
# 🔹 SCC 388 with 3 nodes
#    🔄 Trying all permutations to maximize internal forward weight...
#    ✅ Best internal forward weight (reconsidering all edges): 2.00
# 📊 Initial forward edge weight: 33784.00
# 🎯 Total forward edge weight after optimization: 33803.00
# 33803.0
